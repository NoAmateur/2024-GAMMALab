# %% [markdown]
# In this work, you are required to build a GNN training pipline. Then you can truly use the Graph Neural Network.

# %% [markdown]
# First, we need to download the dataset and load data.

# %%
import torch_geometric.transforms as T
from torch_geometric.datasets import Planetoid
dataset = Planetoid("./", "Cora", transform=T.NormalizeFeatures())
# Out:
# E:\conda\miniconda\envs\PyG\lib\site-packages\torch_geometric\transforms\gdc.py:13: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   return numba.jit(cache=True)(func)
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 8
#       6 x = data.x
#       7 edge_index = data.edge_index
# ----> 8 edge_weight = data.edge_weight
#
# AttributeError: 'Data' object has no attribute 'edge_weight'

# %%
print(data)
# Out:
# Data(edge_index=[2, 10556], test_mask=[2708], train_mask=[2708], val_mask=[2708], x=[2708, 1433], y=[2708])

# %%
data = dataset[0]

x = data.x
edge_index = data.edge_index

# %% [markdown]
# Then, you need to implement a GNN model. You may copy the GCNConv from your work two weeks ago, and build the model with the convolution layers.

# %%
from torch_geometric.nn import MessagePassing
import torch.nn as nn
class PyG_GCNConv(MessagePassing):
    def __init__(self, in_channels, out_channels):
        super(PyG_GCNConv, self).__init__(aggr='add')  # "Add" aggregation.
        self.lin = nn.Linear(in_channels, out_channels)

    def forward(self, x, edge_index, edge_weight=None):
        # x has shape [N, in_channels]
        # edge_index has shape [2, E]
        
        # Step 1: Linearly transform node feature matrix.
        x = self.lin(x)

        # Step 2: Normalize edge weights.
        if edge_weight is None:
            edge_weight = torch.ones((edge_index.size(1), ), dtype=x.dtype, device=edge_index.device)
        row, col = edge_index
        deg = torch.bincount(row, weights=edge_weight, minlength=x.size(0))
        deg_inv_sqrt = deg.pow(-0.5)
        deg_inv_sqrt[torch.isinf(deg_inv_sqrt)] = 0
        norm = deg_inv_sqrt[row] * edge_weight * deg_inv_sqrt[col]

        # Step 3: Start propagating messages.
        return self.propagate(edge_index, x=x, norm=norm)

    def message(self, x_j, norm):
        # x_j has shape [E, out_channels]
        return norm.view(-1, 1) * x_j

class PyG_GCN(nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super(PyG_GCN, self).__init__()
        self.conv1 = PyG_GCNConv(in_channels, hidden_channels)
        self.conv2 = PyG_GCNConv(hidden_channels, out_channels)

    def forward(self, x, edge_index, edge_weight=None):
        x = self.conv1(x, edge_index, edge_weight)
        x = F.relu(x)
        x = self.conv2(x, edge_index, edge_weight)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# Building the training and evaluation part, this is similar to the work in week4. Our downstream task is just node classification.

# %%
import torch
import torch.nn.functional as F
import torch_geometric.transforms as T
from torch_geometric.datasets import Planetoid
from torch_geometric.nn import MessagePassing
import torch.nn as nn
# Build your training pipeline
hidden_dim = 16
lr = 0.001
epochs = 100
model = PyG_GCN(dataset.num_features, hidden_dim, dataset.num_classes)
optimizer = torch.optim.Adam(
    model.parameters(), lr=lr, weight_decay=5e-4)

def train():
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = F.nll_loss(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    return loss.item()
@torch.no_grad()
def test():
    model.eval()
    pred = model(data.x, data.edge_index).argmax(dim=-1)

    accs = []
    for mask in [data.train_mask, data.val_mask, data.test_mask]:
        accs.append(int((pred[mask] == data.y[mask]).sum()) / int(mask.sum()))
    return accs

best_val_acc = 0
test_acc = 0
for epoch in range(1, epochs + 1):
    loss = train()
    train_acc, val_acc, tmp_test_acc = test()
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        test_acc = tmp_test_acc
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train: {train_acc:.4f}, Val: {val_acc:.4f}, Test: {test_acc:.4f}')
# Out:
# Epoch: 001, Loss: 1.9551, Train: 0.1429, Val: 0.1140, Test: 0.1030
# Epoch: 002, Loss: 1.9546, Train: 0.1429, Val: 0.1140, Test: 0.1030
# Epoch: 003, Loss: 1.9541, Train: 0.1429, Val: 0.1140, Test: 0.1030
# Epoch: 004, Loss: 1.9535, Train: 0.1429, Val: 0.1140, Test: 0.1030
# Epoch: 005, Loss: 1.9530, Train: 0.1429, Val: 0.1140, Test: 0.1030
# Epoch:
# Epoch: 085, Loss: 1.8757, Train: 0.4429, Val: 0.2980, Test: 0.2840
# Epoch: 086, Loss: 1.8742, Train: 0.4571, Val: 0.3000, Test: 0.2900
# Epoch: 087, Loss: 1.8728, Train: 0.4571, Val: 0.3000, Test: 0.2900
# Epoch: 088, Loss: 1.8713, Train: 0.4571, Val: 0.3040, Test: 0.3000
# Epoch: 089, Loss: 1.8698, Train: 0.4786, Val: 0.3060, Test: 0.3050
# Epoch: 090, Loss: 1.8683, Train: 0.4786, Val: 0.3060, Test: 0.3050
# Epoch: 091, Loss: 1.8668, Train: 0.4929, Val: 0.3120, Test: 0.3140
# Epoch: 092, Loss: 1.8652, Train: 0.5143, Val: 0.3120, Test: 0.3140
# Epoch: 093, Loss: 1.8637, Train: 0.5286, Val: 0.3140, Test: 0.3270
# Epoch: 094, Loss: 1.8621, Train: 0.5286, Val: 0.3180, Test: 0.3330
# Epoch: 095, Loss: 1.8605, Train: 0.5286, Val: 0.3180, Test: 0.3330
# Epoch: 096, Loss: 1.8590, Train: 0.5357, Val: 0.3340, Test: 0.3460
# Epoch: 097, Loss: 1.8574, Train: 0.5357, Val: 0.3360, Test: 0.3560
# Epoch: 098, Loss: 1.8557, Train: 0.5357, Val: 0.3460, Test: 0.3580
# Epoch: 099, Loss: 1.8541, Train: 0.5500, Val: 0.3580, Test: 0.3610
# Epoch: 100, Loss: 1.8525, Train: 0.5786, Val: 0.3600, Test: 0.3680

# %% [markdown]
# Now, you can train the GCN model with PyG. Next, you may try using the DGL to implement the similiar function.

# %%
import argparse

import dgl
import dgl.nn as dglnn

import torch
import torch.nn as nn
import torch.nn.functional as F


from dgl.data import CoraGraphDataset

try:
    from dgl.transforms import AddSelfLoop
    transform = AddSelfLoop()
    data = CoraGraphDataset(transform=transform)
except ImportError:
    data = CoraGraphDataset()
    g = data[0]
    g = dgl.add_self_loop(g)
g = data[0]
features = g.ndata["feat"]
labels = g.ndata["label"]
masks = g.ndata["train_mask"], g.ndata["val_mask"], g.ndata["test_mask"]


class DGL_GCNConv(nn.Module):
    def __init__(self, in_feats, out_feats):
        super(DGL_GCNConv, self).__init__()
        self.conv = dglnn.GraphConv(in_feats, out_feats, activation=F.relu)

    def forward(self, g, features):
        h = self.conv(g, features)
        return h

class DGL_GCN(nn.Module):
    def __init__(self, in_feats, hidden_feats, out_feats):
        super(DGL_GCN, self).__init__()
        self.layer1 = DGL_GCNConv(in_feats, hidden_feats)
        self.layer2 = DGL_GCNConv(hidden_feats, out_feats)

    def forward(self, g, features):
        h = self.layer1(g, features)
        h = self.layer2(g, h)
        return h
    
def train(g, features, labels, masks, model):
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
    train_mask, val_mask, test_mask = masks
    best_val_acc = 0
    best_model = None

    for epoch in range(200):
        model.train()
        logits = model(g, features)
        loss = F.cross_entropy(logits[train_mask], labels[train_mask])

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_acc = evaluate(g, features, labels, train_mask, model)
        val_acc = evaluate(g, features, labels, val_mask, model)
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_model = model.state_dict()

        print(f'Epoch {epoch:03d} | Loss {loss.item():.4f} | Train Acc {train_acc:.4f} | Val Acc {val_acc:.4f}')

    print("Training finished.")
    # Load the best model
    model.load_state_dict(best_model)
def evaluate(g, features, labels, mask, model):
    model.eval()
    with torch.no_grad():
        logits = model(g, features)
        logits = logits[mask]
        labels = labels[mask]
        _, indices = torch.max(logits, dim=1)
        correct = torch.sum(indices == labels)
        return correct.item() * 1.0 / len(labels)
# Out:
# Downloading C:\Users\lhb\.dgl\cora_v2.zip from https://data.dgl.ai/dataset/cora_v2.zip...
# Extracting file to C:\Users\lhb\.dgl\cora_v2
# Finished data loading and preprocessing.
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done saving data into cached files.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 83
#      80         correct = torch.sum(indices == labels)
#      81         return correct.item() * 1.0 / len(labels)
# ---> 83 model = DGL_GCN(features.shape[1], 16)
#      84 print("Training...")
#      85 train(g, features, labels, masks, model)
#
# TypeError: __init__() missing 1 required positional argument: 'out_feats'

# %%
model = DGL_GCN(features.shape[1], 16,len(torch.unique(labels)))
print("Training...")
train(g, features, labels, masks, model)

# test the model
print("Testing...")
acc = evaluate(g, features, labels, masks[2], model)
print("Test accuracy {:.4f}".format(acc))
# Out:
# Training...
# Epoch 000 | Loss 1.9461 | Train Acc 0.2643 | Val Acc 0.1660
# Epoch 001 | Loss 1.9440 | Train Acc 0.3857 | Val Acc 0.2620
# Epoch 002 | Loss 1.9403 | Train Acc 0.4286 | Val Acc 0.2700
# Epoch 003 | Loss 1.9354 | Train Acc 0.3857 | Val Acc 0.2700
# Epoch 004 | Loss 1.9304 | Train Acc 0.3786 | Val Acc 0.2580
# Epoch 005 | Loss 1.9245 | Train Acc 0.4000 | Val Acc 0.2520
# Epoch 006 | Loss 1.9184 | Train Acc 0.4071 | Val Acc 0.2820
# Epoch 007 | Loss 1.9119 | Train Acc 0.5000 | Val Acc 0.3280
# Epoch 008 | Loss 1.9048 | Train Acc 0.5643 | Val Acc 0.3940
# Epoch 009 | Loss 1.8973 | Train Acc 0.6429 | Val Acc 0.4460
# Epoch 010 | Loss 1.8894 | Train Acc 0.6643 | Val Acc 0.4980
# Epoch 011 | Loss 1.8812 | Train Acc 0.6571 | Val Acc 0.5200
# Epoch 012 | Loss 1.8726 | Train Acc 0.6643 | Val Acc 0.5360
# Epoch 013 | Loss 1.8635 | Train Acc 0.6643 | Val Acc 0.5420
# Epoch 014 | Loss 1.8539 | Train Acc 0.6571 | Val Acc 0.5380
# Epoch 015 | Loss 1.8441 | Train Acc 0.6571 | Val Acc 0.5380
# Epoch 016 | Loss 1.8339 | Train Acc 0.6643 | Val Acc 0.5420
# Epoch 017 | Loss 1.8233 | Train Acc 0.6643 | Val Acc 0.5420
# Epoch 018 | Loss 1.8123 | Train Acc 0.6714 | Val Acc 0.5440
# Epoch 019 | Loss 1.8010 | Train Acc 0.6643 | Val Acc 0.5500
# Epoch 020 | Loss 1.7892 | Train Acc 0.6643 | Val Acc 0.5480
# Epoch 021 | Loss 1.7770 | Train Acc 0.6643 | Val Acc 0.5540
# Epoch 022 | Loss 1.7645 | Train Acc 0.6643 | Val Acc 0.5580
# Epoch 023 | Loss 1.7517 | Train Acc 0.6643 | Val Acc 0.5600
# Epoch 024 | Loss 1.7384 | Train Acc 0.6643 | Val Acc 0.5640
# Epoch 025 | Loss 1.7249 | Train Acc 0.6643 | Val Acc 0.5660
# Epoch 026 | Loss 1.7110 | Train Acc 0.6643 | Val Acc 0.5700
# Epoch 027 | Loss 1.6968 | Train Acc 0.6643 | Val Acc 0.5700
# Epoch 028 | Loss 1.6823 | Train Acc 0.6643 | Val Acc 0.5660
# Epoch 029 | Loss 1.6675 | Train Acc 0.6643 | Val Acc 0.5660
# Epoch 030 | Loss 1.6524 | Train Acc 0.6643 | Val Acc 0.5700
# Epoch 031 | Loss 1.6371 | Train Acc 0.6643 | Val Acc 0.5720
# Epoch 032 | Loss 1.6215 | Train Acc 0.6643 | Val Acc 0.5780
# Epoch 033 | Loss 1.6057 | Train Acc 0.6714 | Val Acc 0.5800
# Epoch 034 | Loss 1.5897 | Train Acc 0.6714 | Val Acc 0.5820
# Epoch 035 | Loss 1.5736 | Train Acc 0.6714 | Val Acc 0.5820
# Epoch 036 | Loss 1.5573 | Train Acc 0.6786 | Val Acc 0.5840
# Epoch 037 | Loss 1.5409 | Train Acc 0.6786 | Val Acc 0.5860
# Epoch 038 | Loss 1.5245 | Train Acc 0.6786 | Val Acc 0.5860
# Epoch 039 | Loss 1.5081 | Train Acc 0.6786 | Val Acc 0.5920
# Epoch 040 | Loss 1.4917 | Train Acc 0.6786 | Val Acc 0.5940
# Epoch 041 | Loss 1.4753 | Train Acc 0.6857 | Val Acc 0.6020
# Epoch 042 | Loss 1.4590 | Train Acc 0.6857 | Val Acc 0.6040
# Epoch 043 | Loss 1.4428 | Train Acc 0.6857 | Val Acc 0.6060
# Epoch 044 | Loss 1.4268 | Train Acc 0.6857 | Val Acc 0.6080
# Epoch 045 | Loss 1.4109 | Train Acc 0.6857 | Val Acc 0.6120
# Epoch 046 | Loss 1.3952 | Train Acc 0.6857 | Val Acc 0.6120
# Epoch 047 | Loss 1.3798 | Train Acc 0.6857 | Val Acc 0.6120
# Epoch 048 | Loss 1.3647 | Train Acc 0.6857 | Val Acc 0.6120
# Epoch 049 | Loss 1.3498 | Train Acc 0.6929 | Val Acc 0.6120
# Epoch 050 | Loss 1.3352 | Train Acc 0.6929 | Val Acc 0.6120
# Epoch 051 | Loss 1.3209 | Train Acc 0.6929 | Val Acc 0.6140
# Epoch 052 | Loss 1.3070 | Train Acc 0.6929 | Val Acc 0.6140
# Epoch 053 | Loss 1.2933 | Train Acc 0.6929 | Val Acc 0.6140
# Epoch 054 | Loss 1.2801 | Train Acc 0.6929 | Val Acc 0.6160
# Epoch 055 | Loss 1.2671 | Train Acc 0.6929 | Val Acc 0.6140
# Epoch 056 | Loss 1.2545 | Train Acc 0.6929 | Val Acc 0.6160
# Epoch 057 | Loss 1.2422 | Train Acc 0.6929 | Val Acc 0.6160
# Epoch 058 | Loss 1.2302 | Train Acc 0.6929 | Val Acc 0.6140
# Epoch 059 | Loss 1.2186 | Train Acc 0.6929 | Val Acc 0.6120
# Epoch 060 | Loss 1.2072 | Train Acc 0.6929 | Val Acc 0.6100
# Epoch 061 | Loss 1.1962 | Train Acc 0.6929 | Val Acc 0.6120
# Epoch 062 | Loss 1.1856 | Train Acc 0.6929 | Val Acc 0.6120
# Epoch 063 | Loss 1.1752 | Train Acc 0.6929 | Val Acc 0.6120
# Epoch 064 | Loss 1.1651 | Train Acc 0.6929 | Val Acc 0.6120
# Epoch 065 | Loss 1.1553 | Train Acc 0.6929 | Val Acc 0.6140
# Epoch 066 | Loss 1.1458 | Train Acc 0.6929 | Val Acc 0.6120
# Epoch 067 | Loss 1.1365 | Train Acc 0.6929 | Val Acc 0.6120
# Epoch 068 | Loss 1.1274 | Train Acc 0.6929 | Val Acc 0.6100
# Epoch 069 | Loss 1.1187 | Train Acc 0.6929 | Val Acc 0.6120
# Epoch 070 | Loss 1.1102 | Train Acc 0.7000 | Val Acc 0.6100
# Epoch 071 | Loss 1.1020 | Train Acc 0.7000 | Val Acc 0.6120
# Epoch 072 | Loss 1.0940 | Train Acc 0.7071 | Val Acc 0.6140
# Epoch 073 | Loss 1.0863 | Train Acc 0.7071 | Val Acc 0.6100
# Epoch 074 | Loss 1.0788 | Train Acc 0.7071 | Val Acc 0.6100
# Epoch 075 | Loss 1.0715 | Train Acc 0.7071 | Val Acc 0.6140
# Epoch 076 | Loss 1.0644 | Train Acc 0.7071 | Val Acc 0.6160
# Epoch 077 | Loss 1.0576 | Train Acc 0.7071 | Val Acc 0.6120
# Epoch 078 | Loss 1.0510 | Train Acc 0.7071 | Val Acc 0.6140
# Epoch 079 | Loss 1.0446 | Train Acc 0.7071 | Val Acc 0.6140
# Epoch 080 | Loss 1.0384 | Train Acc 0.7071 | Val Acc 0.6180
# Epoch 081 | Loss 1.0325 | Train Acc 0.7071 | Val Acc 0.6160
# Epoch 082 | Loss 1.0267 | Train Acc 0.7071 | Val Acc 0.6120
# Epoch 083 | Loss 1.0210 | Train Acc 0.7071 | Val Acc 0.6160
# Epoch 084 | Loss 1.0155 | Train Acc 0.7071 | Val Acc 0.6140
# Epoch 085 | Loss 1.0101 | Train Acc 0.7071 | Val Acc 0.6120
# Epoch 086 | Loss 1.0049 | Train Acc 0.7071 | Val Acc 0.6160
# Epoch 087 | Loss 0.9997 | Train Acc 0.7071 | Val Acc 0.6200
# Epoch 088 | Loss 0.9948 | Train Acc 0.7071 | Val Acc 0.6180
# Epoch 089 | Loss 0.9899 | Train Acc 0.7071 | Val Acc 0.6160
# Epoch 090 | Loss 0.9852 | Train Acc 0.7071 | Val Acc 0.6180
# Epoch 091 | Loss 0.9806 | Train Acc 0.7071 | Val Acc 0.6180
# Epoch 092 | Loss 0.9762 | Train Acc 0.7143 | Val Acc 0.6160
# Epoch 093 | Loss 0.9718 | Train Acc 0.7071 | Val Acc 0.6180
# Epoch 094 | Loss 0.9676 | Train Acc 0.7143 | Val Acc 0.6160
# Epoch 095 | Loss 0.9635 | Train Acc 0.7071 | Val Acc 0.6180
# Epoch 096 | Loss 0.9594 | Train Acc 0.7071 | Val Acc 0.6180
# Epoch 097 | Loss 0.9557 | Train Acc 0.7143 | Val Acc 0.6180
# Epoch 098 | Loss 0.9518 | Train Acc 0.7143 | Val Acc 0.6180
# Epoch 099 | Loss 0.9481 | Train Acc 0.7143 | Val Acc 0.6180
# Epoch 100 | Loss 0.9445 | Train Acc 0.7214 | Val Acc 0.6180
# Epoch 101 | Loss 0.9408 | Train Acc 0.7071 | Val Acc 0.6120
# Epoch 102 | Loss 0.9373 | Train Acc 0.7143 | Val Acc 0.6180
# Epoch 103 | Loss 0.9337 | Train Acc 0.7143 | Val Acc 0.6180
# Epoch 104 | Loss 0.9303 | Train Acc 0.7214 | Val Acc 0.6180
# Epoch 105 | Loss 0.9269 | Train Acc 0.7143 | Val Acc 0.6180
# Epoch 106 | Loss 0.9237 | Train Acc 0.7143 | Val Acc 0.6180
# Epoch 107 | Loss 0.9204 | Train Acc 0.7071 | Val Acc 0.6180
# Epoch 108 | Loss 0.9174 | Train Acc 0.7214 | Val Acc 0.6180
# Epoch 109 | Loss 0.9143 | Train Acc 0.7143 | Val Acc 0.6180
# Epoch 110 | Loss 0.9114 | Train Acc 0.7143 | Val Acc 0.6180
# Epoch 111 | Loss 0.9084 | Train Acc 0.7214 | Val Acc 0.6180
# Epoch 112 | Loss 0.9055 | Train Acc 0.7143 | Val Acc 0.6180
# Epoch 113 | Loss 0.9028 | Train Acc 0.7214 | Val Acc 0.6180
# Epoch 114 | Loss 0.9001 | Train Acc 0.7143 | Val Acc 0.6180
# Epoch 115 | Loss 0.8974 | Train Acc 0.7143 | Val Acc 0.6180
# Epoch 116 | Loss 0.8948 | Train Acc 0.7143 | Val Acc 0.6180
# Epoch 117 | Loss 0.8921 | Train Acc 0.7071 | Val Acc 0.6160
# Epoch 118 | Loss 0.8894 | Train Acc 0.7214 | Val Acc 0.6180
# Epoch 119 | Loss 0.8870 | Train Acc 0.7143 | Val Acc 0.6160
# Epoch 120 | Loss 0.8845 | Train Acc 0.7143 | Val Acc 0.6160
# Epoch 121 | Loss 0.8821 | Train Acc 0.7214 | Val Acc 0.6180
# Epoch 122 | Loss 0.8797 | Train Acc 0.7143 | Val Acc 0.6160
# Epoch 123 | Loss 0.8774 | Train Acc 0.7214 | Val Acc 0.6160
# Epoch 124 | Loss 0.8753 | Train Acc 0.7214 | Val Acc 0.6180
# Epoch 125 | Loss 0.8730 | Train Acc 0.7357 | Val Acc 0.6160
# Epoch 126 | Loss 0.8707 | Train Acc 0.7214 | Val Acc 0.6180
# Epoch 127 | Loss 0.8687 | Train Acc 0.7286 | Val Acc 0.6160
# Epoch 128 | Loss 0.8665 | Train Acc 0.7286 | Val Acc 0.6160
# Epoch 129 | Loss 0.8645 | Train Acc 0.7286 | Val Acc 0.6200
# Epoch 130 | Loss 0.8624 | Train Acc 0.7286 | Val Acc 0.6180
# Epoch 131 | Loss 0.8602 | Train Acc 0.7357 | Val Acc 0.6160
# Epoch 132 | Loss 0.8583 | Train Acc 0.7357 | Val Acc 0.6180
# Epoch 133 | Loss 0.8564 | Train Acc 0.7286 | Val Acc 0.6180
# Epoch 134 | Loss 0.8544 | Train Acc 0.7214 | Val Acc 0.6180
# Epoch 135 | Loss 0.8525 | Train Acc 0.7357 | Val Acc 0.6180
# Epoch 136 | Loss 0.8507 | Train Acc 0.7429 | Val Acc 0.6160
# Epoch 137 | Loss 0.8489 | Train Acc 0.7500 | Val Acc 0.6180
# Epoch 138 | Loss 0.8472 | Train Acc 0.7429 | Val Acc 0.6180
# Epoch 139 | Loss 0.8453 | Train Acc 0.7429 | Val Acc 0.6180
# Epoch 140 | Loss 0.8436 | Train Acc 0.7214 | Val Acc 0.6140
# Epoch 141 | Loss 0.8421 | Train Acc 0.7286 | Val Acc 0.6180
# Epoch 142 | Loss 0.8403 | Train Acc 0.7357 | Val Acc 0.6220
# Epoch 143 | Loss 0.8386 | Train Acc 0.7214 | Val Acc 0.6180
# Epoch 144 | Loss 0.8370 | Train Acc 0.7286 | Val Acc 0.6160
# Epoch 145 | Loss 0.8355 | Train Acc 0.7500 | Val Acc 0.6200
# Epoch 146 | Loss 0.8337 | Train Acc 0.7429 | Val Acc 0.6200
# Epoch 147 | Loss 0.8324 | Train Acc 0.7500 | Val Acc 0.6200
# Epoch 148 | Loss 0.8306 | Train Acc 0.7357 | Val Acc 0.6180
# Epoch 149 | Loss 0.8293 | Train Acc 0.7357 | Val Acc 0.6180
# Epoch 150 | Loss 0.8277 | Train Acc 0.7429 | Val Acc 0.6200
# Epoch 151 | Loss 0.8261 | Train Acc 0.7429 | Val Acc 0.6200
# Epoch 152 | Loss 0.8246 | Train Acc 0.7429 | Val Acc 0.6140
# Epoch 153 | Loss 0.8232 | Train Acc 0.7357 | Val Acc 0.6200
# Epoch 154 | Loss 0.8218 | Train Acc 0.7357 | Val Acc 0.6200
# Epoch 155 | Loss 0.8204 | Train Acc 0.7357 | Val Acc 0.6180
# Epoch 156 | Loss 0.8189 | Train Acc 0.7357 | Val Acc 0.6180
# Epoch 157 | Loss 0.8178 | Train Acc 0.7357 | Val Acc 0.6180
# Epoch 158 | Loss 0.8164 | Train Acc 0.7429 | Val Acc 0.6180
# Epoch 159 | Loss 0.8149 | Train Acc 0.7429 | Val Acc 0.6160
# Epoch 160 | Loss 0.8138 | Train Acc 0.7500 | Val Acc 0.6180
# Epoch 161 | Loss 0.8123 | Train Acc 0.7429 | Val Acc 0.6180
# Epoch 162 | Loss 0.8112 | Train Acc 0.7429 | Val Acc 0.6180
# Epoch 163 | Loss 0.8099 | Train Acc 0.7357 | Val Acc 0.6180
# Epoch 164 | Loss 0.8086 | Train Acc 0.7286 | Val Acc 0.6120
# Epoch 165 | Loss 0.8074 | Train Acc 0.7286 | Val Acc 0.6160
# Epoch 166 | Loss 0.8061 | Train Acc 0.7357 | Val Acc 0.6160
# Epoch 167 | Loss 0.8050 | Train Acc 0.7500 | Val Acc 0.6160
# Epoch 168 | Loss 0.8037 | Train Acc 0.7429 | Val Acc 0.6120
# Epoch 169 | Loss 0.8026 | Train Acc 0.7357 | Val Acc 0.6140
# Epoch 170 | Loss 0.8015 | Train Acc 0.7357 | Val Acc 0.6180
# Epoch 171 | Loss 0.8003 | Train Acc 0.7500 | Val Acc 0.6120
# Epoch 172 | Loss 0.7990 | Train Acc 0.7429 | Val Acc 0.6140
# Epoch 173 | Loss 0.7979 | Train Acc 0.7429 | Val Acc 0.6180
# Epoch 174 | Loss 0.7970 | Train Acc 0.7429 | Val Acc 0.6120
# Epoch 175 | Loss 0.7957 | Train Acc 0.7429 | Val Acc 0.6100
# Epoch 176 | Loss 0.7948 | Train Acc 0.7357 | Val Acc 0.6140
# Epoch 177 | Loss 0.7936 | Train Acc 0.7357 | Val Acc 0.6120
# Epoch 178 | Loss 0.7929 | Train Acc 0.7500 | Val Acc 0.6120
# Epoch 179 | Loss 0.7917 | Train Acc 0.7643 | Val Acc 0.6100
# Epoch 180 | Loss 0.7906 | Train Acc 0.7500 | Val Acc 0.6120
# Epoch 181 | Loss 0.7897 | Train Acc 0.7357 | Val Acc 0.6160
# Epoch 182 | Loss 0.7886 | Train Acc 0.7357 | Val Acc 0.6100
# Epoch 183 | Loss 0.7877 | Train Acc 0.7500 | Val Acc 0.6100
# Epoch 184 | Loss 0.7866 | Train Acc 0.7500 | Val Acc 0.6180
# Epoch 185 | Loss 0.7857 | Train Acc 0.7429 | Val Acc 0.6100
# Epoch 186 | Loss 0.7847 | Train Acc 0.7357 | Val Acc 0.6100
# Epoch 187 | Loss 0.7838 | Train Acc 0.7429 | Val Acc 0.6120
# Epoch 188 | Loss 0.7830 | Train Acc 0.7429 | Val Acc 0.6100
# Epoch 189 | Loss 0.7822 | Train Acc 0.7571 | Val Acc 0.6100
# Epoch 190 | Loss 0.7811 | Train Acc 0.7429 | Val Acc 0.6140
# Epoch 191 | Loss 0.7804 | Train Acc 0.7571 | Val Acc 0.6080
# Epoch 192 | Loss 0.7795 | Train Acc 0.7571 | Val Acc 0.6080
# Epoch 193 | Loss 0.7785 | Train Acc 0.7500 | Val Acc 0.6100
# Epoch 194 | Loss 0.7776 | Train Acc 0.7500 | Val Acc 0.6100
# Epoch 195 | Loss 0.7766 | Train Acc 0.7500 | Val Acc 0.6080
# Epoch 196 | Loss 0.7758 | Train Acc 0.7643 | Val Acc 0.6080
# Epoch 197 | Loss 0.7748 | Train Acc 0.7500 | Val Acc 0.6100
# Epoch 198 | Loss 0.7739 | Train Acc 0.7357 | Val Acc 0.6080
# Epoch 199 | Loss 0.7733 | Train Acc 0.7357 | Val Acc 0.6100
# Training finished.
# Testing...
# Test accuracy 0.6420

# %% [markdown]
# If you find it hard to implement, you may refer to the official implementation of the GNN training, like [PyG](https://github.com/pyg-team/pytorch_geometric/blob/master/examples/gcn.py) and [DGL](https://github.com/dmlc/dgl/blob/master/examples/pytorch/gcn/train.py).
